# %%
# Import Essential Modules
import wfdb
import ast
import pickle
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from keras import layers
import matplotlib.pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# config trail runs
PTBXL_PATH = "/home/student/Prathamesh's Project Pre-requisites/DataRes/physionet.org/files/ptb-xl/1.0.3/" # path to PTB-XL dataset
SAMPLING_RATE = 100 
NUM_CLASSES = 5
NUM_EPOCHS = 100
BATCH_SIZE = 32
WIDTH = 64 # default width for epoch wise double descent
# Out:
# 2026-03-05 14:31:02.454186: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-05 14:31:02.472502: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-05 14:31:03.154105: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# Load data
def load_ptbxl(path, sampling_rate=100):
    Y = pd.read_csv(path + 'ptbxl_database.csv', index_col='ecg_id')
    Y.scp_codes = Y.scp_codes.apply(ast.literal_eval)

    agg_df = pd.read_csv(path + 'scp_statements.csv', index_col=0)
    agg_df = agg_df[agg_df.diagnostic == 1.0]

    def aggregate_diagnostic(y_dic):
        tmp = set()
        for key in y_dic.keys():
            if key in agg_df.index:
                tmp.add(agg_df.loc[key].diagnostic_class)
            return list(tmp)

    Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)

    # Keep only samples that have at least one diagnostic superclass
    Y = Y[Y['diagnostic_superclass'].map(len) >= 1]

    # Get top 5 classes
    from collections import Counter
    all_labels = [label for sublist in Y['diagnostic_superclass'] for label in sublist]
    top5 = [label for label, _ in Counter(all_labels).most_common(5)]
    print(f"Top 5 classes: {top5}")

    # Filter to samples that have at least one top-5 label
    Y['diagnostic_superclass'] = Y['diagnostic_superclass'].apply(
    lambda x: [l for l in x if l in top5]
    )
    Y = Y[Y['diagnostic_superclass'].map(len) >= 1]

    # Load signals
    filenames = Y.filename_lr if sampling_rate == 100 else Y.filename_hr
    print("Loading signals...")
    X = np.array([wfdb.rdsamp(path + f)[0] for f in filenames]) # (N, 1000, 12)

    # Split use 10 fold stratified sampling
    test_fold = 10 
    val_fold = 9

    X_test = X[np.where(Y.strat_fold == test_fold)]
    Y_test = Y[(Y.strat_fold == test_fold)].diagnostic_superclass

    X_val = X[np.where(Y.strat_fold == val_fold)]
    Y_val = Y[(Y.strat_fold == val_fold)].diagnostic_superclass

    X_train = X[np.where((Y.strat_fold != test_fold) & (Y.strat_fold != val_fold))]
    Y_train  = Y[((Y.strat_fold != test_fold) & (Y.strat_fold != val_fold))].diagnostic_superclass

    # Multi-hot encode
    mlb = MultiLabelBinarizer(classes=top5)
    y_test = mlb.fit_transform(Y_test) # (N, 5) binary matrix
    y_val = mlb.fit_transform(Y_val)
    y_train = mlb.fit_transform(Y_train)

    return X_train, y_train, X_test, y_test, X_val, y_val, top5, mlb

# %%
# Conv1D+BiLSTM Model

# residual block
def residual_block(x, filters, kernel_size = 3, stride=1):
    shortcut = x
    
    # main path
    x = layers.Conv1D(filters, kernel_size, strides = stride, padding = "same", use_bias = False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv1D(filters, kernel_size, strides = stride, padding = "same", use_bias = False)(x)
    x = layers.BatchNormalization()(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv1D(filters, kernel_size = 1, strides = stride, use_bias = False)(shortcut)
    shortcut = layers.BatchNormalization()(shortcut)

    # skip-connection
    x = layers.Add()([shortcut, x])
    x = layers.ReLU()(x)
    return x

def build_model(input_shape = (1000, 12), num_classes = 5, width = 64):
    # Input layers
    InputLayer = layers.Input(shape=input_shape)

    # 1D-CNN Block 1
    x = layers.Conv1D(width, kernel_size = 7, strides = 2, padding = "same", use_bias = False)(InputLayer)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # residual block 1
    x = residual_block(x, width)
    # residual block 2
    x = residual_block(x, width)
    # residual block 3
    x = residual_block(x, width)

    # Bi-LSTM Block 1
    x = layers.Bidirectional(layers.LSTM(units = 64, return_sequences = True))(x)
    x = layers.Bidirectional(layers.LSTM(units = 32, return_sequences = False))(x)

    # Classification Overhead
    OutputLayer = layers.Dense(num_classes, activation = "sigmoid")(x)

    # Model Creation
    return tf.keras.Model(inputs = InputLayer, outputs = OutputLayer, name = "1DCNN_BiLSTM_Z_Model")

# %%
# Define custom metrics

# subclass custom Hamming Loss metric (Not using tensorflow addons here; version clash)
@tf.keras.utils.register_keras_serializable()
class HammingLoss(tf.keras.metrics.Metric):

    def __init__(self, name = "Hamming_loss", **kwargs):
        super(HammingLoss, self).__init__(name = name, **kwargs)
        self.total_mismatches = self.add_weight(name = "Total_mismatches", initializer = 'zeros', dtype = tf.float32)
        self.total_labels = self.add_weight(name = "Total_labels", initializer = 'zeros', dtype = tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):
        # caste predictions and targets in tf.float32
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(tf.greater(y_pred, 0.5), tf.float32)

        # Calculate mismatches
        mismatches = tf.cast((tf.math.count_nonzero(tf.math.not_equal(y_true, y_pred), axis=-1)), tf.float32)

        # Find number of labels and batch size
        num_label = tf.cast(tf.shape(y_true)[-1], tf.float32) # shape is (rows, columns) and columns = number of elements in array
        batch_size = tf.cast(tf.shape(y_true)[0], tf.float32) # shape is (rows, columns) and rows = batch size per array
        
        # Update number of mismatches and total labels count
        self.total_mismatches.assign_add(tf.reduce_sum(mismatches)) # reduce sum adds all the elements in an array (here, instance)
        self.total_labels.assign_add(batch_size * num_label) # total label count = number of labels x batch size per instance

    def result(self):
        return self.total_mismatches / self.total_labels # Hamming Loss formula
    
    def reset_state(self): # reset atttributes
        self.total_mismatches.assign(0.)
        self.total_labels.assign(0.)

# %%
def run_experiment(width = 64, epochs = 100):
    # Load data
    X_train, y_train, X_test, y_test, X_val, y_val, classes, mlb = load_ptbxl(PTBXL_PATH, SAMPLING_RATE)

    # Normalise per-lead
    X_test = (X_test-X_test.mean(axis = 1, keepdims = True)) / (X_test.std(axis = 1, keepdims = True) + 1e-8)
    X_train = (X_train-X_train.mean(axis = 1, keepdims = True)) / (X_train.std(axis = 1, keepdims = True) + 1e-8)
    X_val = (X_val-X_val.mean(axis = 1, keepdims = True)) / (X_val.std(axis = 1, keepdims = True) + 1e-8)
    
    # Build Model
    model = build_model(
    input_shape = (X_train.shape[1], X_train.shape[2]),
    num_classes = len(classes),
    width = width
    )

    # Model summary and parameters number
    model.summary()

    # Adam optimiser
    optimiser = tf.keras.optimizers.Adam(learning_rate = 1e-3)

    # Compile model
    model.compile(
    optimizer = optimiser,
    loss = tf.keras.losses.binary_focal_crossentropy,
    metrics = [tf.keras.metrics.Precision(name = "precision"), tf.keras.metrics.Recall(name = "recall"), HammingLoss()]
    )

    # Decide callbacks
    Callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor = "val_precision", patience = 12, restore_best_weights = True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor = "val_loss", factor = 0.5, patience = 5)
    ]

    # prep run
    history = model.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),
    epochs = epochs,
    callbacks = Callbacks
    )

    return history

# %%
history = run_experiment(width = 64, epochs = 100)
# Out:
# Top 5 classes: ['NORM', 'MI', 'STTC', 'CD', 'HYP']
# Loading signals...
# Model: "1DCNN_BiLSTM_Z_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1000, 12)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 500, 64)   │      5,376 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 500, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ re_lu[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 500, 64)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 500, 64)   │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ re_lu_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 500, 64)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 500, 64)   │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ re_lu_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 500, 64)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 500, 64)   │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 500, 128)  │     66,048 │ re_lu_6[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 64)        │     41,216 │ bidirectional[0]… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 5)         │        325 │ bidirectional_1[… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 189,253 (739.27 KB)
#  Trainable params: 187,973 (734.27 KB)
#  Non-trainable params: 1,280 (5.00 KB)
# Epoch 1/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 87s 157ms/step - Hamming_loss: 0.1475 - loss: 0.0944 - precision: 0.6933 - recall: 0.4707 - val_Hamming_loss: 0.1336 - val_loss: 0.0865 - val_precision: 0.7263 - val_recall: 0.5324 - learning_rate: 0.0010
# Epoch 2/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.1288 - loss: 0.0846 - precision: 0.7466 - recall: 0.5392 - val_Hamming_loss: 0.1280 - val_loss: 0.0833 - val_precision: 0.7529 - val_recall: 0.5362 - learning_rate: 0.0010
# Epoch 3/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.1220 - loss: 0.0798 - precision: 0.7572 - recall: 0.5742 - val_Hamming_loss: 0.1528 - val_loss: 0.0943 - val_precision: 0.6581 - val_recall: 0.4914 - learning_rate: 0.0010
# Epoch 4/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.1204 - loss: 0.0786 - precision: 0.7549 - recall: 0.5896 - val_Hamming_loss: 0.1283 - val_loss: 0.0817 - val_precision: 0.7140 - val_recall: 0.5978 - learning_rate: 0.0010
# Epoch 5/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.1161 - loss: 0.0768 - precision: 0.7720 - recall: 0.5950 - val_Hamming_loss: 0.1183 - val_loss: 0.0792 - val_precision: 0.7603 - val_recall: 0.5964 - learning_rate: 0.0010
# Epoch 6/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.1114 - loss: 0.0735 - precision: 0.7769 - recall: 0.6216 - val_Hamming_loss: 0.1222 - val_loss: 0.0815 - val_precision: 0.7195 - val_recall: 0.6379 - learning_rate: 0.0010
# Epoch 7/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.1083 - loss: 0.0712 - precision: 0.7799 - recall: 0.6386 - val_Hamming_loss: 0.1055 - val_loss: 0.0730 - val_precision: 0.7701 - val_recall: 0.6738 - learning_rate: 0.0010
# Epoch 8/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.1055 - loss: 0.0696 - precision: 0.7823 - recall: 0.6546 - val_Hamming_loss: 0.1132 - val_loss: 0.0729 - val_precision: 0.7530 - val_recall: 0.6458 - learning_rate: 0.0010
# Epoch 9/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0996 - loss: 0.0652 - precision: 0.7929 - recall: 0.6796 - val_Hamming_loss: 0.1075 - val_loss: 0.0698 - val_precision: 0.7686 - val_recall: 0.6617 - learning_rate: 0.0010
# Epoch 10/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0950 - loss: 0.0631 - precision: 0.8028 - recall: 0.6959 - val_Hamming_loss: 0.1060 - val_loss: 0.0686 - val_precision: 0.7735 - val_recall: 0.6645 - learning_rate: 0.0010
# Epoch 11/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0922 - loss: 0.0614 - precision: 0.8089 - recall: 0.7055 - val_Hamming_loss: 0.1014 - val_loss: 0.0678 - val_precision: 0.7692 - val_recall: 0.7046 - learning_rate: 0.0010
# Epoch 12/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0934 - loss: 0.0619 - precision: 0.8088 - recall: 0.6983 - val_Hamming_loss: 0.1082 - val_loss: 0.0707 - val_precision: 0.7654 - val_recall: 0.6622 - learning_rate: 0.0010
# Epoch 13/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0897 - loss: 0.0592 - precision: 0.8123 - recall: 0.7173 - val_Hamming_loss: 0.0985 - val_loss: 0.0675 - val_precision: 0.7807 - val_recall: 0.7060 - learning_rate: 0.0010
# Epoch 14/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0866 - loss: 0.0571 - precision: 0.8198 - recall: 0.7264 - val_Hamming_loss: 0.1012 - val_loss: 0.0703 - val_precision: 0.7700 - val_recall: 0.7046 - learning_rate: 0.0010
# Epoch 15/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0846 - loss: 0.0555 - precision: 0.8249 - recall: 0.7322 - val_Hamming_loss: 0.1029 - val_loss: 0.0679 - val_precision: 0.7737 - val_recall: 0.6860 - learning_rate: 0.0010
# Epoch 16/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0834 - loss: 0.0545 - precision: 0.8260 - recall: 0.7388 - val_Hamming_loss: 0.1061 - val_loss: 0.0705 - val_precision: 0.7661 - val_recall: 0.6757 - learning_rate: 0.0010
# Epoch 17/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0806 - loss: 0.0527 - precision: 0.8325 - recall: 0.7474 - val_Hamming_loss: 0.1011 - val_loss: 0.0705 - val_precision: 0.7740 - val_recall: 0.6986 - learning_rate: 0.0010
# Epoch 18/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0764 - loss: 0.0506 - precision: 0.8411 - recall: 0.7617 - val_Hamming_loss: 0.1046 - val_loss: 0.0682 - val_precision: 0.7656 - val_recall: 0.6874 - learning_rate: 0.0010
# Epoch 19/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0698 - loss: 0.0455 - precision: 0.8562 - recall: 0.7827 - val_Hamming_loss: 0.1029 - val_loss: 0.0735 - val_precision: 0.7664 - val_recall: 0.6981 - learning_rate: 5.0000e-04
# Epoch 20/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0648 - loss: 0.0424 - precision: 0.8670 - recall: 0.7986 - val_Hamming_loss: 0.1056 - val_loss: 0.0778 - val_precision: 0.7550 - val_recall: 0.6990 - learning_rate: 5.0000e-04
# Epoch 21/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0613 - loss: 0.0400 - precision: 0.8739 - recall: 0.8103 - val_Hamming_loss: 0.1048 - val_loss: 0.0796 - val_precision: 0.7560 - val_recall: 0.7028 - learning_rate: 5.0000e-04
# Epoch 22/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0573 - loss: 0.0375 - precision: 0.8834 - recall: 0.8219 - val_Hamming_loss: 0.1096 - val_loss: 0.0843 - val_precision: 0.7448 - val_recall: 0.6878 - learning_rate: 5.0000e-04
# Epoch 23/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 158ms/step - Hamming_loss: 0.0533 - loss: 0.0347 - precision: 0.8904 - recall: 0.8362 - val_Hamming_loss: 0.1118 - val_loss: 0.0898 - val_precision: 0.7380 - val_recall: 0.6836 - learning_rate: 5.0000e-04
# Epoch 24/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 160ms/step - Hamming_loss: 0.0441 - loss: 0.0297 - precision: 0.9116 - recall: 0.8631 - val_Hamming_loss: 0.1070 - val_loss: 0.0927 - val_precision: 0.7475 - val_recall: 0.7018 - learning_rate: 2.5000e-04
# Epoch 25/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 85s 159ms/step - Hamming_loss: 0.0406 - loss: 0.0270 - precision: 0.9200 - recall: 0.8731 - val_Hamming_loss: 0.1070 - val_loss: 0.0963 - val_precision: 0.7479 - val_recall: 0.7018 - learning_rate: 2.5000e-04
