# %%
# Import Essential Modules
import wfdb
import ast
import pickle
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from keras import layers
import matplotlib.pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# config trail runs
PTBXL_PATH = "/home/student/Prathamesh's Project Pre-requisites/DataRes/physionet.org/files/ptb-xl/1.0.3/" # path to PTB-XL dataset
SAMPLING_RATE = 100 
NUM_CLASSES = 5
NUM_EPOCHS = 100
BATCH_SIZE = 32
WIDTH = 64 # default width for epoch wise double descent
# Out:
# 2026-03-06 11:40:59.688229: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-06 11:40:59.706317: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-06 11:41:00.411236: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# Load data
def load_ptbxl(path, sampling_rate=100):
    Y = pd.read_csv(path + 'ptbxl_database.csv', index_col='ecg_id')
    Y.scp_codes = Y.scp_codes.apply(ast.literal_eval)

    agg_df = pd.read_csv(path + 'scp_statements.csv', index_col=0)
    agg_df = agg_df[agg_df.diagnostic == 1.0]

    def aggregate_diagnostic(y_dic):
        tmp = set()
        for key in y_dic.keys():
            if key in agg_df.index:
                tmp.add(agg_df.loc[key].diagnostic_class)
            return list(tmp)

    Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)

    # Keep only samples that have at least one diagnostic superclass
    Y = Y[Y['diagnostic_superclass'].map(len) >= 1]

    # Get top 5 classes
    from collections import Counter
    all_labels = [label for sublist in Y['diagnostic_superclass'] for label in sublist]
    top5 = [label for label, _ in Counter(all_labels).most_common(5)]
    print(f"Top 5 classes: {top5}")

    # Filter to samples that have at least one top-5 label
    Y['diagnostic_superclass'] = Y['diagnostic_superclass'].apply(
    lambda x: [l for l in x if l in top5]
    )
    Y = Y[Y['diagnostic_superclass'].map(len) >= 1]

    # Load signals
    filenames = Y.filename_lr if sampling_rate == 100 else Y.filename_hr
    print("Loading signals...")
    X = np.array([wfdb.rdsamp(path + f)[0] for f in filenames]) # (N, 1000, 12)

    # Split use 10 fold stratified sampling
    test_fold = 10 
    val_fold = 9

    X_test = X[np.where(Y.strat_fold == test_fold)]
    Y_test = Y[(Y.strat_fold == test_fold)].diagnostic_superclass

    X_val = X[np.where(Y.strat_fold == val_fold)]
    Y_val = Y[(Y.strat_fold == val_fold)].diagnostic_superclass

    X_train = X[np.where((Y.strat_fold != test_fold) & (Y.strat_fold != val_fold))]
    Y_train  = Y[((Y.strat_fold != test_fold) & (Y.strat_fold != val_fold))].diagnostic_superclass

    # Multi-hot encode
    mlb = MultiLabelBinarizer(classes=top5)
    y_test = mlb.fit_transform(Y_test) # (N, 5) binary matrix
    y_val = mlb.fit_transform(Y_val)
    y_train = mlb.fit_transform(Y_train)

    return X_train, y_train, X_test, y_test, X_val, y_val, top5, mlb

# %%
# Conv1D+BiLSTM Model

# residual block
def residual_block(x, filters, kernel_size = 3, stride=1):
    shortcut = x
    
    # main path
    x = layers.Conv1D(filters, kernel_size, strides = stride, padding = "same", use_bias = False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv1D(filters, kernel_size, strides = stride, padding = "same", use_bias = False)(x)
    x = layers.BatchNormalization()(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv1D(filters, kernel_size = 1, strides = stride, use_bias = False)(shortcut)
    shortcut = layers.BatchNormalization()(shortcut)

    # skip-connection
    x = layers.Add()([shortcut, x])
    x = layers.ReLU()(x)
    return x

def build_model(input_shape = (1000, 12), num_classes = 5, width = 64):
    # Input layers
    InputLayer = layers.Input(shape=input_shape)

    # 1D-CNN Block 1
    x = layers.Conv1D(width, kernel_size = 7, strides = 2, padding = "same", use_bias = False)(InputLayer)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    

    # residual block 1
    x = residual_block(x, width)
    # residual block 2
    x = residual_block(x, width)
    # residual block 3
    x = residual_block(x, width)

    # Bi-LSTM Block 1 (redacted for less training time)
    # x = layers.Bidirectional(layers.LSTM(units = 64, return_sequences = True))(x)
    # x = layers.Dropout(0.3)(x)
    # x = layers.Bidirectional(layers.LSTM(units = 32, return_sequences = False))(x)
    x = layers.GlobalAveragePooling1D()(x)
    # Classification Overhead
    x = layers.Dense(units = 64, activation = "relu")(x)
    # x = layers.Dropout(0.3)(x)
    OutputLayer = layers.Dense(num_classes, activation = "sigmoid")(x)

    # Model Creation
    return tf.keras.Model(inputs = InputLayer, outputs = OutputLayer, name = "1DCNN_BiLSTM_Z_Model")

# %%
# Define custom metrics

# subclass custom Hamming Loss metric (Not using tensorflow addons here; version clash)
@tf.keras.utils.register_keras_serializable()
class HammingLoss(tf.keras.metrics.Metric):

    def __init__(self, name = "Hamming_loss", **kwargs):
        super(HammingLoss, self).__init__(name = name, **kwargs)
        self.total_mismatches = self.add_weight(name = "Total_mismatches", initializer = 'zeros', dtype = tf.float32)
        self.total_labels = self.add_weight(name = "Total_labels", initializer = 'zeros', dtype = tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):
        # caste predictions and targets in tf.float32
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(tf.greater(y_pred, 0.5), tf.float32)

        # Calculate mismatches
        mismatches = tf.cast((tf.math.count_nonzero(tf.math.not_equal(y_true, y_pred), axis=-1)), tf.float32)

        # Find number of labels and batch size
        num_label = tf.cast(tf.shape(y_true)[-1], tf.float32) # shape is (rows, columns) and columns = number of elements in array
        batch_size = tf.cast(tf.shape(y_true)[0], tf.float32) # shape is (rows, columns) and rows = batch size per array
        
        # Update number of mismatches and total labels count
        self.total_mismatches.assign_add(tf.reduce_sum(mismatches)) # reduce sum adds all the elements in an array (here, instance)
        self.total_labels.assign_add(batch_size * num_label) # total label count = number of labels x batch size per instance

    def result(self):
        return self.total_mismatches / self.total_labels # Hamming Loss formula
    
    def reset_state(self): # reset atttributes
        self.total_mismatches.assign(0.)
        self.total_labels.assign(0.)

# %%
def run_experiment(width = 64, epochs = 100):
    # Load data
    X_train, y_train, X_test, y_test, X_val, y_val, classes, mlb = load_ptbxl(PTBXL_PATH, SAMPLING_RATE)

    # Normalise per-lead
    X_test = (X_test-X_test.mean(axis = 1, keepdims = True)) / (X_test.std(axis = 1, keepdims = True) + 1e-8)
    X_train = (X_train-X_train.mean(axis = 1, keepdims = True)) / (X_train.std(axis = 1, keepdims = True) + 1e-8)
    X_val = (X_val-X_val.mean(axis = 1, keepdims = True)) / (X_val.std(axis = 1, keepdims = True) + 1e-8)
    
    # Build Model
    model = build_model(
    input_shape = (X_train.shape[1], X_train.shape[2]),
    num_classes = len(classes),
    width = width
    )

    # Model summary and parameters number
    model.summary()

    # Adam optimiser
    optimiser = tf.keras.optimizers.Adam(learning_rate = 1e-3)

    # Compile model
    model.compile(
    optimizer = optimiser,
    loss = tf.keras.losses.binary_focal_crossentropy,
    metrics = [tf.keras.metrics.Precision(name = "precision"), 
               tf.keras.metrics.Recall(name = "recall", thresholds = 0.30),
               tf.keras.metrics.AUC(curve = "ROC", multi_label = True),
               HammingLoss()]
    )

    # Decide callbacks
    Callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor = "val_precision", patience = 8, restore_best_weights = True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor = "val_loss", factor = 0.5, patience = 5)
    ]

    print(f"--------------------------------Training commenced--------------------------------")
    print(f"Training Set loading.....\n")

    # prep run
    history = model.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),
    epochs = epochs,
    callbacks = Callbacks
    )

    print(f"\n--------------------------------Training completed--------------------------------")
    print(f"Evaluation Set loading.....\n")
    
    # eval results
    performance = model.evaluate(
    x = X_test,
    y = y_test,
    batch_size = 32 
    )
    
    print(f"\nEvalution Done!")
    
    return history, performance

# %%
history, performance = run_experiment(width = 64, epochs = 100)
# Out:
# Top 5 classes: ['NORM', 'MI', 'STTC', 'CD', 'HYP']
# Loading signals...
# Model: "1DCNN_BiLSTM_Z_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1000, 12)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 500, 64)   │      5,376 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 500, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ re_lu[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 500, 64)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 500, 64)   │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ re_lu_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 500, 64)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 500, 64)   │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ re_lu_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 500, 64)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 500, 64)   │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_6[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      4,160 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 5)         │        325 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 86,149 (336.52 KB)
#  Trainable params: 84,869 (331.52 KB)
#  Non-trainable params: 1,280 (5.00 KB)
# --------------------------------Training commenced--------------------------------
# Training Set loading.....
#
# Epoch 1/100
#   3/534 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - Hamming_loss: 0.2906 - auc: 0.4446 - loss: 0.1499 - precision: 0.1615 - recall: 0.8333
# 2026-03-06 11:41:50.955806: E tensorflow/core/util/util.cc:131] oneDNN supports DT_BOOL only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - Hamming_loss: 0.1185 - auc: 0.8631 - loss: 0.0759 - precision: 0.7672 - recall: 0.9179 - val_Hamming_loss: 0.1197 - val_auc: 0.8741 - val_loss: 0.0760 - val_precision: 0.7394 - val_recall: 0.9011 - learning_rate: 0.0010
# Epoch 2/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.1041 - auc: 0.8954 - loss: 0.0674 - precision: 0.7869 - recall: 0.9248 - val_Hamming_loss: 0.1159 - val_auc: 0.8881 - val_loss: 0.0732 - val_precision: 0.7499 - val_recall: 0.9141 - learning_rate: 0.0010
# Epoch 3/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0982 - auc: 0.9063 - loss: 0.0641 - precision: 0.7980 - recall: 0.9300 - val_Hamming_loss: 0.1158 - val_auc: 0.8944 - val_loss: 0.0751 - val_precision: 0.7486 - val_recall: 0.9048 - learning_rate: 0.0010
# Epoch 4/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0949 - auc: 0.9148 - loss: 0.0615 - precision: 0.8036 - recall: 0.9314 - val_Hamming_loss: 0.1098 - val_auc: 0.8999 - val_loss: 0.0703 - val_precision: 0.7518 - val_recall: 0.9169 - learning_rate: 0.0010
# Epoch 5/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0918 - auc: 0.9200 - loss: 0.0600 - precision: 0.8085 - recall: 0.9343 - val_Hamming_loss: 0.1251 - val_auc: 0.8979 - val_loss: 0.0769 - val_precision: 0.7249 - val_recall: 0.9053 - learning_rate: 0.0010
# Epoch 6/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0903 - auc: 0.9241 - loss: 0.0586 - precision: 0.8110 - recall: 0.9359 - val_Hamming_loss: 0.1103 - val_auc: 0.9011 - val_loss: 0.0700 - val_precision: 0.7779 - val_recall: 0.9407 - learning_rate: 0.0010
# Epoch 7/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0880 - auc: 0.9273 - loss: 0.0575 - precision: 0.8149 - recall: 0.9367 - val_Hamming_loss: 0.1026 - val_auc: 0.9036 - val_loss: 0.0687 - val_precision: 0.7840 - val_recall: 0.9197 - learning_rate: 0.0010
# Epoch 8/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0877 - auc: 0.9300 - loss: 0.0566 - precision: 0.8165 - recall: 0.9397 - val_Hamming_loss: 0.1038 - val_auc: 0.9051 - val_loss: 0.0663 - val_precision: 0.7869 - val_recall: 0.9468 - learning_rate: 0.0010
# Epoch 9/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0850 - auc: 0.9339 - loss: 0.0553 - precision: 0.8220 - recall: 0.9418 - val_Hamming_loss: 0.1250 - val_auc: 0.8874 - val_loss: 0.0819 - val_precision: 0.7231 - val_recall: 0.8824 - learning_rate: 0.0010
# Epoch 10/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0826 - auc: 0.9371 - loss: 0.0540 - precision: 0.8281 - recall: 0.9439 - val_Hamming_loss: 0.1096 - val_auc: 0.9021 - val_loss: 0.0719 - val_precision: 0.7554 - val_recall: 0.9090 - learning_rate: 0.0010
# Epoch 11/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0824 - auc: 0.9386 - loss: 0.0533 - precision: 0.8274 - recall: 0.9456 - val_Hamming_loss: 0.1208 - val_auc: 0.8977 - val_loss: 0.0744 - val_precision: 0.7341 - val_recall: 0.9393 - learning_rate: 0.0010
# Epoch 12/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0800 - auc: 0.9427 - loss: 0.0518 - precision: 0.8318 - recall: 0.9478 - val_Hamming_loss: 0.1167 - val_auc: 0.8932 - val_loss: 0.0802 - val_precision: 0.7218 - val_recall: 0.8605 - learning_rate: 0.0010
# Epoch 13/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0804 - auc: 0.9452 - loss: 0.0512 - precision: 0.8302 - recall: 0.9484 - val_Hamming_loss: 0.1061 - val_auc: 0.8984 - val_loss: 0.0756 - val_precision: 0.7548 - val_recall: 0.8852 - learning_rate: 0.0010
# Epoch 14/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0710 - auc: 0.9555 - loss: 0.0463 - precision: 0.8515 - recall: 0.9551 - val_Hamming_loss: 0.1054 - val_auc: 0.9019 - val_loss: 0.0697 - val_precision: 0.7616 - val_recall: 0.9057 - learning_rate: 5.0000e-04
# Epoch 15/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0691 - auc: 0.9596 - loss: 0.0448 - precision: 0.8548 - recall: 0.9569 - val_Hamming_loss: 0.1010 - val_auc: 0.9017 - val_loss: 0.0696 - val_precision: 0.7681 - val_recall: 0.8964 - learning_rate: 5.0000e-04
# Epoch 16/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 19s 36ms/step - Hamming_loss: 0.0664 - auc: 0.9613 - loss: 0.0436 - precision: 0.8587 - recall: 0.9561 - val_Hamming_loss: 0.1005 - val_auc: 0.9008 - val_loss: 0.0735 - val_precision: 0.7626 - val_recall: 0.8922 - learning_rate: 5.0000e-04
#
# --------------------------------Training completed--------------------------------
# Evaluation Set loading.....
#
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - Hamming_loss: 0.1012 - auc: 0.8950 - loss: 0.0679 - precision: 0.7981 - recall: 0.9351
#
# Evalution Done!
