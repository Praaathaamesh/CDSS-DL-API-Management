# %%
# Importing important packages
import pickle
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import layers
from sklearn.neighbors import NearestNeighbors
# Out:
# 2026-02-13 08:36:14.742630: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-13 08:36:14.761454: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-13 08:36:15.866378: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ## Import Signal and label Data

# %%
# load signal data
Path = "/home/student/Prathamesh's Project Pre-requisites/CodeSpace/DL/CheckPoint2/"
signal_files = ["/X_TRAIN.pkl","/X_TEST.pkl","/X_VAL.pkl",]

x_train = list()
x_test = list()
x_val = list()

for i in signal_files:
    if i == "/X_TRAIN.pkl":
        with open(Path + "/X_TRAIN.pkl", "rb") as f:
            x_train = pickle.load(f)
    elif i == "/X_TEST.pkl":
        with open(Path + "/X_TEST.pkl", "rb") as f:
            x_test = pickle.load(f)
    elif i == "/X_VAL.pkl":
        with open(Path + "/X_VAL.pkl", "rb") as f:
            x_val = pickle.load(f)

# convert to from np arrays to tensors
x_train = tf.convert_to_tensor(x_train, dtype = tf.float32)
x_test = tf.convert_to_tensor(x_test, dtype = tf.float32)
x_val = tf.convert_to_tensor(x_val, dtype = tf.float32)

# %%
# Verify shapes
print(f"The shapes are:\n- x_train is {x_train.shape} \n- x_test is {x_test.shape} \n- x_val is {x_val.shape}")
# Out:
# The shapes are:
# - x_train is (17084, 1000, 12)
# - x_test is (2158, 1000, 12)
# - x_val is (2146, 1000, 12)

# %%
# load label data
Path = "/home/student/Prathamesh's Project Pre-requisites/CodeSpace/DL/CheckPoint2/"
label_files = ["/Y_TRAIN.pkl","/Y_TEST.pkl","/Y_VAL.pkl",]

for i in label_files:
    if i == "/Y_TRAIN.pkl":
        with open(Path + "/Y_TRAIN.pkl", "rb") as f:
            y_train = pickle.load(f)
    elif i == "/Y_TEST.pkl":
        with open(Path + "/Y_TEST.pkl", "rb") as f:
            y_test = pickle.load(f)
    elif i == "/Y_VAL.pkl":
        with open(Path + "/Y_VAL.pkl", "rb") as f:
            y_val = pickle.load(f)

# process labels
def multihot_encode(pd_series_labels):
    # pandas series to list
    list_labels = pd_series_labels.to_list()

    # convert to ragged vector
    ragged_list_labels = tf.ragged.constant(list_labels)

    # setup string lookup and adapt
    str_lookup_layer = layers.StringLookup(output_mode = "multi_hot")
    str_lookup_layer.adapt(ragged_list_labels) 
    multi_hot_labels = str_lookup_layer(ragged_list_labels)

    return multi_hot_labels

# appyl multi hot encoding
y_train = tf.cast(multihot_encode(y_train),dtype = tf.float32)
y_test = tf.cast(multihot_encode(y_test),dtype = tf.float32)
y_val = tf.cast(multihot_encode(y_val),dtype = tf.float32)

# %%
# Verify shapes
print(f"The shapes are:\n- y_train is {y_train.shape} \n- y_test is {y_test.shape} \n- y_val is {y_val.shape}")
# Out:
# The shapes are:
# - y_train is (17084, 6)
# - y_test is (2158, 6)
# - y_val is (2146, 6)

# %% [markdown]
# ## Model Creation

# %%
# Conv1D+BiLSTM Model

# residual block
def residual_block(x, filters, kernel_size, stride=1):
    shortcut = x
    
    # main path
    x = layers.Conv1D(filters, kernel_size, strides = stride, padding = "same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv1D(filters, kernel_size, strides = stride, padding = "same")(x)
    x = layers.BatchNormalization()(x)

    # skip-connection
    x = layers.Add()([shortcut, x])
    x = layers.Activation("relu")(x)
    return x

# Input layers
InputLayer = layers.Input(shape=(1000, 12))

# 1D-CNN Block 1
x = layers.Conv1D(filters = 32, kernel_size = 3, strides = 1, activation = "relu", padding = "same")(InputLayer)
x = layers.BatchNormalization()(x)
x = layers.MaxPool1D(pool_size = 2)(x) 
x = layers.Dropout(0.3)(x) 

# 1D-CNN Block 2
x = layers.Conv1D(filters = 64, kernel_size = 5, strides = 1, activation = "relu", padding = "same")(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPool1D(pool_size = 2)(x) 
x = layers.Dropout(0.3)(x) 

# 1D-CNN Block 3  
x = layers.Conv1D(filters = 128, kernel_size = 5, strides = 1, activation = "relu", padding = "same")(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPool1D(pool_size = 2)(x) 
x = layers.Dropout(0.3)(x) 

# residual block 1
x = residual_block(x, filters = 128, kernel_size = 3)

# residual block 2
x = residual_block(x, filters = 128, kernel_size = 3)

# Bi-LSTM Block 1
x = layers.Bidirectional(layers.LSTM(units = 128, return_sequences = True))(x)
x = layers.Dropout(0.4)(x)
x = layers.Bidirectional(layers.LSTM(units = 128, return_sequences = False))(x)

# Classification Overhead
x = layers.Dense(units = 128, activation = "relu")(x)
x = layers.Dropout(0.3)(x)
x = layers.Dense(units = 64, activation = "relu")(x)
x = layers.Dropout(0.3)(x)
OutputLayer = layers.Dense(units = 6, activation = "sigmoid")(x)

# Model Creation
model = tf.keras.Model(inputs = InputLayer, outputs = OutputLayer, name = "1DCNN_BiLSTM_Z_Model")

# %%
# Define custom metrics

# subclass custom Hamming Loss metric (Not using tensorflow addons here; version clash)
@tf.keras.utils.register_keras_serializable()
class HammingLoss(tf.keras.metrics.Metric):

    def __init__(self, name = "Hamming_loss", **kwargs):
        super(HammingLoss, self).__init__(name = name, **kwargs)
        self.total_mismatches = self.add_weight(name = "Total_mismatches", initializer = 'zeros', dtype = tf.float32)
        self.total_labels = self.add_weight(name = "Total_labels", initializer = 'zeros', dtype = tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):
        # caste predictions and targets in tf.float32
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(tf.greater(y_pred, 0.5), tf.float32)

        # Calculate mismatches
        mismatches = tf.cast((tf.math.count_nonzero(tf.math.not_equal(y_true, y_pred), axis=-1)), tf.float32)

        # Find number of labels and batch size
        num_label = tf.cast(tf.shape(y_true)[-1], tf.float32) # shape is (rows, columns) and columns = number of elements in array
        batch_size = tf.cast(tf.shape(y_true)[0], tf.float32) # shape is (rows, columns) and rows = batch size per array
        
        # Update number of mismatches and total labels count
        self.total_mismatches.assign_add(tf.reduce_sum(mismatches)) # reduce sum adds all the elements in an array (here, instance)
        self.total_labels.assign_add(batch_size * num_label) # total label count = number of labels x batch size per instance

    def result(self):
        return self.total_mismatches / self.total_labels # Hamming Loss formula
    
    def reset_state(self): # reset atttributes
        self.total_mismatches.assign(0.)
        self.total_labels.assign(0.)

# subclass custom Hamming score metric
@tf.keras.utils.register_keras_serializable()
class HammingScore(tf.keras.metrics.Metric):

    def __init__(self, name = "Hamming_score", **kwargs):
        super(HammingScore, self).__init__(name = name, **kwargs)
        self.total_mismatches = self.add_weight(name = "Total_mismatches", initializer = 'zeros', dtype = tf.float32)
        self.total_labels = self.add_weight(name = "Total_labels", initializer = 'zeros', dtype = tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):
        # caste predictions and targets in tf.float32
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(tf.greater(y_pred, 0.5), tf.float32)

        # Calculate mismatches
        mismatches = tf.cast((tf.math.count_nonzero(tf.math.not_equal(y_true, y_pred), axis=-1)), tf.float32)

        # Find number of labels and batch size
        num_label = tf.cast(tf.shape(y_true)[-1], tf.float32) # shape is (rows, columns) and columns = number of elements in array
        batch_size = tf.cast(tf.shape(y_true)[0], tf.float32) # shape is (rows, columns) and rows = batch size per array
        
        # Update number of mismatches and total labels count
        self.total_mismatches.assign_add(tf.reduce_sum(mismatches)) # reduce sum adds all the elements in an array (here, instance)
        self.total_labels.assign_add(batch_size * num_label) # total label count = number of labels x batch size per instance

    def result(self):
        return 1 - (self.total_mismatches / self.total_labels) # Hamming Score = 1 - Hamming loss
    
    def reset_state(self): # reset atttributes
        self.total_mismatches.assign(0.)
        self.total_labels.assign(0.)

# %%
# model compilation (loss function and optimiser)
roc_auc = tf.keras.metrics.AUC(curve = "ROC", name = "ROC-AUC")
accuracy = tf.keras.metrics.BinaryAccuracy(name = "Accuracy")
recall = tf.keras.metrics.Recall(name = "Recall", thresholds = 0.35)
precision = tf.keras.metrics.Precision(name = "Precision", thresholds = 0.4)
F2_score = tf.keras.metrics.FBetaScore(name = "F2", beta = 2.0, average = "weighted", threshold = 0.35)

model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate = 1e-3),
              loss = tf.keras.losses.binary_focal_crossentropy,
              metrics = [accuracy,
                         roc_auc,
                         F2_score,
                         recall,
                         precision,
                         HammingLoss(), HammingScore()])

# %%
# get summary
model.summary()
# Out:
# Model: "1DCNN_BiLSTM_Z_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1000, 12)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 1000, 32)  │      1,184 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 1000, 32)  │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 500, 32)   │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 500, 32)   │          0 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 500, 64)   │     10,304 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 250, 64)   │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 250, 64)   │          0 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 250, 128)  │     41,088 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 250, 128)  │        512 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 125, 128)  │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 125, 128)  │          0 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 125, 128)  │     49,280 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 125, 128)  │        512 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 125, 128)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 125, 128)  │     49,280 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 125, 128)  │        512 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 125, 128)  │          0 │ dropout_2[0][0],  │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 125, 128)  │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 125, 128)  │     49,280 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 125, 128)  │        512 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 125, 128)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 125, 128)  │     49,280 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 125, 128)  │        512 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 125, 128)  │          0 │ activation_1[0][… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 125, 128)  │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 125, 256)  │    263,168 │ activation_3[0][… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 125, 256)  │          0 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 256)       │    394,240 │ dropout_3[0][0]   │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     32,896 │ bidirectional_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64)        │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 6)         │        390 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 951,590 (3.63 MB)
#  Trainable params: 950,118 (3.62 MB)
#  Non-trainable params: 1,472 (5.75 KB)

# %%
# visualise model
tf.keras.utils.plot_model(model,
                          dpi = 100,
                          to_file = 'Final_Z.png',
                          show_shapes = True,
                          show_dtype = True,
                          show_layer_names = True,
                          show_layer_activations = True)

# %% [markdown]
# ## Trail Runs

# %%
# set callbacks
Callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor = "val_Precision", patience = 12, restore_best_weights = True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor = "val_loss", factor = 0.5, patience = 5)
]

# %%
# train  model
History = model.fit(
    x = x_train,
    y = y_train,
    validation_data =(x_val, y_val),
    epochs = 100,
    batch_size = 32,
    callbacks = Callbacks
)
# Out:
# Epoch 1/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 58s 101ms/step - Accuracy: 0.7756 - F2: 0.6285 - Hamming_loss: 0.2244 - Hamming_score: 0.7756 - Precision: 0.3127 - ROC-AUC: 0.6935 - Recall: 0.8881 - loss: 0.1215 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.2935 - val_ROC-AUC: 0.7148 - val_Recall: 0.9038 - val_loss: 0.1169 - learning_rate: 0.0010
# Epoch 2/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 57s 106ms/step - Accuracy: 0.7823 - F2: 0.6387 - Hamming_loss: 0.2177 - Hamming_score: 0.7823 - Precision: 0.3254 - ROC-AUC: 0.7103 - Recall: 0.9208 - loss: 0.1176 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.4450 - val_ROC-AUC: 0.7149 - val_Recall: 0.9038 - val_loss: 0.1165 - learning_rate: 0.0010
# Epoch 3/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7832 - F2: 0.6350 - Hamming_loss: 0.2168 - Hamming_score: 0.7832 - Precision: 0.3305 - ROC-AUC: 0.7117 - Recall: 0.9190 - loss: 0.1171 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.4450 - val_ROC-AUC: 0.7153 - val_Recall: 0.9038 - val_loss: 0.1164 - learning_rate: 0.0010
# Epoch 4/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 106ms/step - Accuracy: 0.7835 - F2: 0.6311 - Hamming_loss: 0.2165 - Hamming_score: 0.7835 - Precision: 0.3372 - ROC-AUC: 0.7136 - Recall: 0.9144 - loss: 0.1167 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3389 - val_ROC-AUC: 0.7172 - val_Recall: 0.9038 - val_loss: 0.1163 - learning_rate: 0.0010
# Epoch 5/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7834 - F2: 0.6275 - Hamming_loss: 0.2166 - Hamming_score: 0.7834 - Precision: 0.3350 - ROC-AUC: 0.7138 - Recall: 0.9106 - loss: 0.1167 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3198 - val_ROC-AUC: 0.7143 - val_Recall: 0.9038 - val_loss: 0.1163 - learning_rate: 0.0010
# Epoch 6/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7834 - F2: 0.6290 - Hamming_loss: 0.2166 - Hamming_score: 0.7834 - Precision: 0.3386 - ROC-AUC: 0.7140 - Recall: 0.9118 - loss: 0.1166 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3716 - val_ROC-AUC: 0.7159 - val_Recall: 0.9038 - val_loss: 0.1163 - learning_rate: 0.0010
# Epoch 7/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 106ms/step - Accuracy: 0.7834 - F2: 0.6265 - Hamming_loss: 0.2166 - Hamming_score: 0.7834 - Precision: 0.3431 - ROC-AUC: 0.7138 - Recall: 0.9095 - loss: 0.1165 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3483 - val_ROC-AUC: 0.7147 - val_Recall: 0.9038 - val_loss: 0.1164 - learning_rate: 0.0010
# Epoch 8/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7835 - F2: 0.6253 - Hamming_loss: 0.2165 - Hamming_score: 0.7835 - Precision: 0.3450 - ROC-AUC: 0.7149 - Recall: 0.9085 - loss: 0.1164 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3279 - val_ROC-AUC: 0.7156 - val_Recall: 0.9038 - val_loss: 0.1163 - learning_rate: 0.0010
# Epoch 9/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7835 - F2: 0.6259 - Hamming_loss: 0.2165 - Hamming_score: 0.7835 - Precision: 0.3412 - ROC-AUC: 0.7155 - Recall: 0.9087 - loss: 0.1164 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3214 - val_ROC-AUC: 0.7154 - val_Recall: 0.9038 - val_loss: 0.1164 - learning_rate: 0.0010
# Epoch 10/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7835 - F2: 0.6249 - Hamming_loss: 0.2165 - Hamming_score: 0.7835 - Precision: 0.3455 - ROC-AUC: 0.7173 - Recall: 0.9078 - loss: 0.1164 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3463 - val_ROC-AUC: 0.7144 - val_Recall: 0.9038 - val_loss: 0.1164 - learning_rate: 5.0000e-04
# Epoch 11/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7836 - F2: 0.6244 - Hamming_loss: 0.2164 - Hamming_score: 0.7836 - Precision: 0.3503 - ROC-AUC: 0.7169 - Recall: 0.9076 - loss: 0.1163 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3439 - val_ROC-AUC: 0.7172 - val_Recall: 0.9038 - val_loss: 0.1162 - learning_rate: 5.0000e-04
# Epoch 12/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7838 - F2: 0.6246 - Hamming_loss: 0.2162 - Hamming_score: 0.7838 - Precision: 0.3450 - ROC-AUC: 0.7178 - Recall: 0.9076 - loss: 0.1163 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3724 - val_ROC-AUC: 0.7159 - val_Recall: 0.9038 - val_loss: 0.1163 - learning_rate: 5.0000e-04
# Epoch 13/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7838 - F2: 0.6251 - Hamming_loss: 0.2162 - Hamming_score: 0.7838 - Precision: 0.3496 - ROC-AUC: 0.7196 - Recall: 0.9081 - loss: 0.1162 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3481 - val_ROC-AUC: 0.7149 - val_Recall: 0.9038 - val_loss: 0.1163 - learning_rate: 5.0000e-04
# Epoch 14/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 56s 105ms/step - Accuracy: 0.7835 - F2: 0.6250 - Hamming_loss: 0.2165 - Hamming_score: 0.7835 - Precision: 0.3523 - ROC-AUC: 0.7208 - Recall: 0.9080 - loss: 0.1162 - val_Accuracy: 0.7836 - val_F2: 0.6200 - val_Hamming_loss: 0.2164 - val_Hamming_score: 0.7836 - val_Precision: 0.3415 - val_ROC-AUC: 0.7146 - val_Recall: 0.9038 - val_loss: 0.1164 - learning_rate: 5.0000e-04

# %%
# evaluate model
Evaluation_result = model.evaluate(
    x = x_test,
    y = y_test,
    batch_size = 32)
# Out:
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - Accuracy: 0.7844 - F2: 0.6216 - Hamming_loss: 0.2156 - Hamming_score: 0.7844 - Precision: 0.4462 - ROC-AUC: 0.7172 - Recall: 0.9062 - loss: 0.1161

# %%
# sample prediction
results = model.predict(x = x_test[99:100])
print(results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# [[0.05062224 0.4908761  0.39192456 0.388721   0.37998864 0.3106474 ]]
