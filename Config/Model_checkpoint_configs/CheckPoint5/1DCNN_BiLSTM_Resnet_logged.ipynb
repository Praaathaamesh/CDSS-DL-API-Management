# %%
# Import Essential Modules
import wfdb
import ast
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from keras import layers
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# config trail runs
PTBXL_PATH = "/home/student/Prathamesh's Project Pre-requisites/DataRes/physionet.org/files/ptb-xl/1.0.3/" # path to PTB-XL dataset
LOG_DIR = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
SAMPLING_RATE = 100 
NUM_CLASSES = 5
NUM_EPOCHS = 100
BATCH_SIZE = 32
WIDTH = 64 # default width for epoch wise double descent
# Out:
# 2026-04-17 11:00:19.380071: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-17 11:00:19.398293: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-17 11:00:20.089407: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# Load data
def load_ptbxl(path, sampling_rate=100):
    Y = pd.read_csv(path + 'ptbxl_database.csv', index_col='ecg_id')
    Y.scp_codes = Y.scp_codes.apply(ast.literal_eval)

    agg_df = pd.read_csv(path + 'scp_statements.csv', index_col=0)
    agg_df = agg_df[agg_df.diagnostic == 1.0]

    def aggregate_diagnostic(y_dic):
        tmp = set()
        for key in y_dic.keys():
            if key in agg_df.index:
                tmp.add(agg_df.loc[key].diagnostic_class)
        return list(tmp)

    Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)

    # parse HYP_HR entries
    target_hyp_codes = {'STD', 'STE', 'HVOLT', 'LVOLT', 'VCLVH'}
    def relabel_hyp_hr(row):
        curr_class = row['diagnostic_superclass']
        scp_dict = row['scp_codes']
        if 'HYP' in curr_class:
            if any(code in scp_dict for code in target_hyp_codes):
                return ['HYP_HR']
            else:
                return ['HYP']
        return curr_class
    
    Y['diagnostic_superclass'] = Y.apply(relabel_hyp_hr, axis = 1)
    print(Y['diagnostic_superclass'].value_counts())
    
    # Keep only samples that have at least one diagnostic superclass
    Y = Y[Y['diagnostic_superclass'].map(len) >= 1]

    # Get top 6 classes
    from collections import Counter
    all_labels = [label for sublist in Y['diagnostic_superclass'] for label in sublist]
    top6 = [label for label, _ in Counter(all_labels).most_common(6)]
    print(f'Top 6 classes: {top6}')

    # Filter to samples that have at least one top-5 label
    Y['diagnostic_superclass'] = Y['diagnostic_superclass'].apply(
    lambda x: [l for l in x if l in top6]
    )
    Y = Y[Y['diagnostic_superclass'].map(len) >= 1]

    # Load signals
    filenames = Y.filename_lr if sampling_rate == 100 else Y.filename_hr
    print('Loading signals...')
    X = np.array([wfdb.rdsamp(path + f)[0] for f in filenames]) # (N, 1000, 12)

    # Split use 10 fold stratified sampling
    test_fold = 10 
    val_fold = 9

    X_test = X[np.where(Y.strat_fold == test_fold)]
    Y_test = Y[(Y.strat_fold == test_fold)].diagnostic_superclass

    X_val = X[np.where(Y.strat_fold == val_fold)]
    Y_val = Y[(Y.strat_fold == val_fold)].diagnostic_superclass

    X_train = X[np.where((Y.strat_fold != test_fold) & (Y.strat_fold != val_fold))]
    Y_train  = Y[((Y.strat_fold != test_fold) & (Y.strat_fold != val_fold))].diagnostic_superclass

    # Multi-hot encode
    mlb = MultiLabelBinarizer(classes=top6)
    mlb.fit([top6])
    y_test = mlb.transform(Y_test) # (N, 6) binary matrix
    y_val = mlb.transform(Y_val)
    y_train = mlb.transform(Y_train)

    return X_train, y_train, X_test, y_test, X_val, y_val, top6, mlb

# %%
# Conv1D+BiLSTM Model

# residual block
def residual_block(x, filters, kernel_size = 3, stride=1):
    shortcut = x
    
    # main path
    x = layers.Conv1D(filters, kernel_size, strides = stride, padding = "same", use_bias = False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv1D(filters, kernel_size, strides = stride, padding = "same", use_bias = False)(x)
    x = layers.BatchNormalization()(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv1D(filters, kernel_size = 1, strides = stride, use_bias = False)(shortcut)
    shortcut = layers.BatchNormalization()(shortcut)

    # skip-connection
    x = layers.Add()([shortcut, x])
    x = layers.ReLU()(x)
    return x

def build_model(input_shape = (1000, 12), num_classes = 5, width = 64):
    # Input layers
    InputLayer = layers.Input(shape=input_shape)

    # 1D-CNN Block 1
    x = layers.Conv1D(width, kernel_size = 7, strides = 2, padding = "same", use_bias = False)(InputLayer)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    

    # residual block 1
    x = residual_block(x, width)
    # residual block 2
    x = residual_block(x, width)
    # residual block 3
    x = residual_block(x, width)

    # Bi-LSTM Block 1 (redacted for less training time)
    x = layers.Bidirectional(layers.LSTM(units = 64, return_sequences = True))(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Bidirectional(layers.LSTM(units = 32, return_sequences = False))(x)
    
    # x = layers.GlobalAveragePooling1D()(x)
    # Classification Overhead
    x = layers.Dense(units = 64, activation = "relu")(x)
    x = layers.Dropout(0.3)(x)
    OutputLayer = layers.Dense(num_classes, activation = "sigmoid")(x)

    # Model Creation
    return tf.keras.Model(inputs = InputLayer, outputs = OutputLayer, name = "1DCNN_BiLSTM_Z_Model")

# %%
# Define custom metrics

# subclass custom Hamming Loss metric (Not using tensorflow addons here; version clash)
@tf.keras.utils.register_keras_serializable()
class HammingLoss(tf.keras.metrics.Metric):

    def __init__(self, name = "Hamming_loss", **kwargs):
        super(HammingLoss, self).__init__(name = name, **kwargs)
        self.total_mismatches = self.add_weight(name = "Total_mismatches", initializer = 'zeros', dtype = tf.float32)
        self.total_labels = self.add_weight(name = "Total_labels", initializer = 'zeros', dtype = tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):
        # caste predictions and targets in tf.float32
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(tf.greater(y_pred, 0.5), tf.float32)

        # Calculate mismatches
        mismatches = tf.cast((tf.math.count_nonzero(tf.math.not_equal(y_true, y_pred), axis=-1)), tf.float32)

        # Find number of labels and batch size
        num_label = tf.cast(tf.shape(y_true)[-1], tf.float32) # shape is (rows, columns) and columns = number of elements in array
        batch_size = tf.cast(tf.shape(y_true)[0], tf.float32) # shape is (rows, columns) and rows = batch size per array
        
        # Update number of mismatches and total labels count
        self.total_mismatches.assign_add(tf.reduce_sum(mismatches)) # reduce sum adds all the elements in an array (here, instance)
        self.total_labels.assign_add(batch_size * num_label) # total label count = number of labels x batch size per instance

    def result(self):
        return self.total_mismatches / self.total_labels # Hamming Loss formula
    
    def reset_state(self): # reset atttributes
        self.total_mismatches.assign(0.)
        self.total_labels.assign(0.)

# subclass custom Hamming score metric
@tf.keras.utils.register_keras_serializable()
class HammingScore(tf.keras.metrics.Metric):

    def __init__(self, name = "Hamming_score", **kwargs):
        super(HammingScore, self).__init__(name = name, **kwargs)
        self.total_mismatches = self.add_weight(name = "Total_mismatches", initializer = 'zeros', dtype = tf.float32)
        self.total_labels = self.add_weight(name = "Total_labels", initializer = 'zeros', dtype = tf.float32)

    def update_state(self, y_true, y_pred, sample_weight=None):
        # caste predictions and targets in tf.float32
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(tf.greater(y_pred, 0.5), tf.float32)

        # Calculate mismatches
        mismatches = tf.cast((tf.math.count_nonzero(tf.math.not_equal(y_true, y_pred), axis=-1)), tf.float32)

        # Find number of labels and batch size
        num_label = tf.cast(tf.shape(y_true)[-1], tf.float32) # shape is (rows, columns) and columns = number of elements in array
        batch_size = tf.cast(tf.shape(y_true)[0], tf.float32) # shape is (rows, columns) and rows = batch size per array
        
        # Update number of mismatches and total labels count
        self.total_mismatches.assign_add(tf.reduce_sum(mismatches)) # reduce sum adds all the elements in an array (here, instance)
        self.total_labels.assign_add(batch_size * num_label) # total label count = number of labels x batch size per instance

    def result(self):
        return 1 - (self.total_mismatches / self.total_labels) # Hamming Score = 1 - Hamming loss
    
    def reset_state(self): # reset atttributes
        self.total_mismatches.assign(0.)
        self.total_labels.assign(0.)

# %%
def run_experiment(width = 64, epochs = 100, sample = 0):
    # Load data
    X_train, y_train, X_test, y_test, X_val, y_val, classes, mlb = load_ptbxl(PTBXL_PATH, SAMPLING_RATE)

    # Normalise per-lead
    X_test = (X_test-X_test.mean(axis = 1, keepdims = True)) / (X_test.std(axis = 1, keepdims = True) + 1e-8)
    X_train = (X_train-X_train.mean(axis = 1, keepdims = True)) / (X_train.std(axis = 1, keepdims = True) + 1e-8)
    X_val = (X_val-X_val.mean(axis = 1, keepdims = True)) / (X_val.std(axis = 1, keepdims = True) + 1e-8)
    
    # Build Model
    model = build_model(
    input_shape = (X_train.shape[1], X_train.shape[2]),
    num_classes = len(classes),
    width = width
    )

    # Model summary and parameters number
    model.summary()

    # Adam optimiser
    optimiser = tf.keras.optimizers.Adam(learning_rate = 1e-3)

    # Compile model
    model.compile(
    optimizer = optimiser,
    loss = tf.keras.losses.binary_focal_crossentropy,
    metrics = [tf.keras.metrics.Precision(name = "precision"), 
               tf.keras.metrics.Recall(name = "recall", thresholds = 0.20),
               tf.keras.metrics.AUC(name="ROC-AUC", curve = "ROC", multi_label = True),
               tf.keras.metrics.FBetaScore(name = "F2", beta = 2.0, average="micro", threshold=0.20),
               HammingLoss(),
               HammingScore()]
    )

    # Decide callbacks
    Callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor = "val_precision", patience = 8, restore_best_weights = True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor = "val_loss", factor = 0.5, patience = 5),
    tf.keras.callbacks.TensorBoard(log_dir=LOG_DIR, histogram_freq=1)
    ]

    print(f"--------------------------------Training commenced--------------------------------")
    print(f"Training Set loading.....\n")

    # prep run
    history = model.fit(
    X_train, y_train,
    validation_data = (X_val, y_val),
    epochs = epochs,
    callbacks = Callbacks
    )

    print(f"\n--------------------------------Training completed--------------------------------")
    print(f"Evaluation Set loading.....\n")
    
    # eval results
    performance = model.evaluate(
    x = X_test,
    y = y_test,
    batch_size = 32 
    )
    
    print(f"\n--------------------------------Evalution done!--------------------------------\n")
    
    # predict sample
    print(f"Showing predictions for sample number {sample}")
    prediction = model.predict(x = X_test[sample:(sample+1)])
    print(prediction)

    # Save model
    print(f"\n--------------------------------Save current model--------------------------------")
    print(f"\nSaving model....")
    model.save('optimal_hr_model.keras')

    print(f"\n--------------------------------Model saved successfully!-------------------------")

    return history, performance, prediction

# %%
history, performance, prediction = run_experiment(width = 64, epochs = 100, sample = 0)
# Out:
# diagnostic_superclass
# [NORM]              9069
# [MI]                2532
# [STTC]              2400
# [HYP]               1966
# [CD]                1708
# [MI, CD]            1297
# [HYP_HR]             683
# [STTC, MI]           599
# [STTC, CD]           471
# []                   411
# [NORM, CD]           407
# [STTC, MI, CD]       223
# [STTC, NORM]          28
# [STTC, NORM, CD]       5
# Name: count, dtype: int64
# Top 6 classes: ['NORM', 'MI', 'CD', 'STTC', 'HYP', 'HYP_HR']
# Loading signals...
# Model: "1DCNN_BiLSTM_Z_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 1000, 12)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 500, 64)   │      5,376 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 500, 64)   │        256 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ re_lu[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 500, 64)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 500, 64)   │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ re_lu_2[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 500, 64)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 500, 64)   │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 500, 64)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 500, 64)   │     12,288 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ re_lu_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 500, 64)   │        256 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 500, 64)   │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 500, 64)   │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 500, 128)  │     66,048 │ re_lu_6[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 500, 128)  │          0 │ bidirectional[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 64)        │     41,216 │ dropout[0][0]     │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │      4,160 │ bidirectional_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 6)         │        390 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 193,478 (755.77 KB)
#  Trainable params: 192,198 (750.77 KB)
#  Non-trainable params: 1,280 (5.00 KB)
# --------------------------------Training commenced--------------------------------
# Training Set loading.....
#
# Epoch 1/100
# 2026-04-17 11:01:11.572912: E tensorflow/core/util/util.cc:131] oneDNN supports DT_BOOL only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 89s 161ms/step - F2: 0.5693 - Hamming_loss: 0.1641 - Hamming_score: 0.8359 - ROC-AUC: 0.6876 - loss: 0.1027 - precision: 0.6388 - recall: 0.9861 - val_F2: 0.6187 - val_Hamming_loss: 0.1674 - val_Hamming_score: 0.8326 - val_ROC-AUC: 0.7156 - val_loss: 0.1145 - val_precision: 0.6036 - val_recall: 0.9257 - learning_rate: 0.0010
# Epoch 2/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 87s 164ms/step - F2: 0.5774 - Hamming_loss: 0.1542 - Hamming_score: 0.8458 - ROC-AUC: 0.7153 - loss: 0.0976 - precision: 0.6898 - recall: 0.9818 - val_F2: 0.5780 - val_Hamming_loss: 0.1445 - val_Hamming_score: 0.8555 - val_ROC-AUC: 0.7537 - val_loss: 0.0894 - val_precision: 0.7261 - val_recall: 0.9851 - learning_rate: 0.0010
# Epoch 3/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 87s 163ms/step - F2: 0.5911 - Hamming_loss: 0.1436 - Hamming_score: 0.8564 - ROC-AUC: 0.7625 - loss: 0.0901 - precision: 0.7084 - recall: 0.9794 - val_F2: 0.5726 - val_Hamming_loss: 0.1430 - val_Hamming_score: 0.8570 - val_ROC-AUC: 0.7643 - val_loss: 0.0871 - val_precision: 0.7126 - val_recall: 0.9887 - learning_rate: 0.0010
# Epoch 4/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 164ms/step - F2: 0.5979 - Hamming_loss: 0.1371 - Hamming_score: 0.8629 - ROC-AUC: 0.7789 - loss: 0.0867 - precision: 0.7319 - recall: 0.9803 - val_F2: 0.6135 - val_Hamming_loss: 0.1364 - val_Hamming_score: 0.8636 - val_ROC-AUC: 0.7846 - val_loss: 0.0843 - val_precision: 0.7526 - val_recall: 0.9742 - learning_rate: 0.0010
# Epoch 5/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 164ms/step - F2: 0.6058 - Hamming_loss: 0.1358 - Hamming_score: 0.8642 - ROC-AUC: 0.7928 - loss: 0.0846 - precision: 0.7285 - recall: 0.9805 - val_F2: 0.6248 - val_Hamming_loss: 0.1296 - val_Hamming_score: 0.8704 - val_ROC-AUC: 0.7945 - val_loss: 0.0843 - val_precision: 0.7235 - val_recall: 0.9693 - learning_rate: 0.0010
# Epoch 6/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 164ms/step - F2: 0.6109 - Hamming_loss: 0.1313 - Hamming_score: 0.8687 - ROC-AUC: 0.7987 - loss: 0.0834 - precision: 0.7383 - recall: 0.9799 - val_F2: 0.5875 - val_Hamming_loss: 0.1345 - val_Hamming_score: 0.8655 - val_ROC-AUC: 0.7978 - val_loss: 0.0836 - val_precision: 0.7182 - val_recall: 0.9875 - learning_rate: 0.0010
# Epoch 7/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 164ms/step - F2: 0.6196 - Hamming_loss: 0.1251 - Hamming_score: 0.8749 - ROC-AUC: 0.8161 - loss: 0.0800 - precision: 0.7396 - recall: 0.9811 - val_F2: 0.5995 - val_Hamming_loss: 0.1357 - val_Hamming_score: 0.8643 - val_ROC-AUC: 0.8023 - val_loss: 0.0834 - val_precision: 0.7293 - val_recall: 0.9867 - learning_rate: 0.0010
# Epoch 8/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 164ms/step - F2: 0.6241 - Hamming_loss: 0.1206 - Hamming_score: 0.8794 - ROC-AUC: 0.8264 - loss: 0.0778 - precision: 0.7467 - recall: 0.9817 - val_F2: 0.6355 - val_Hamming_loss: 0.1376 - val_Hamming_score: 0.8624 - val_ROC-AUC: 0.8100 - val_loss: 0.0837 - val_precision: 0.6778 - val_recall: 0.9705 - learning_rate: 0.0010
# Epoch 9/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 164ms/step - F2: 0.6330 - Hamming_loss: 0.1143 - Hamming_score: 0.8857 - ROC-AUC: 0.8398 - loss: 0.0755 - precision: 0.7615 - recall: 0.9805 - val_F2: 0.6434 - val_Hamming_loss: 0.1218 - val_Hamming_score: 0.8782 - val_ROC-AUC: 0.8275 - val_loss: 0.0775 - val_precision: 0.7330 - val_recall: 0.9750 - learning_rate: 0.0010
# Epoch 10/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 164ms/step - F2: 0.6397 - Hamming_loss: 0.1120 - Hamming_score: 0.8880 - ROC-AUC: 0.8494 - loss: 0.0739 - precision: 0.7653 - recall: 0.9814 - val_F2: 0.6391 - val_Hamming_loss: 0.1138 - val_Hamming_score: 0.8862 - val_ROC-AUC: 0.8374 - val_loss: 0.0747 - val_precision: 0.7584 - val_recall: 0.9758 - learning_rate: 0.0010
# Epoch 11/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 87s 163ms/step - F2: 0.6478 - Hamming_loss: 0.1086 - Hamming_score: 0.8914 - ROC-AUC: 0.8610 - loss: 0.0717 - precision: 0.7743 - recall: 0.9799 - val_F2: 0.6670 - val_Hamming_loss: 0.1125 - val_Hamming_score: 0.8875 - val_ROC-AUC: 0.8535 - val_loss: 0.0733 - val_precision: 0.7438 - val_recall: 0.9770 - learning_rate: 0.0010
# Epoch 12/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.6555 - Hamming_loss: 0.1066 - Hamming_score: 0.8934 - ROC-AUC: 0.8684 - loss: 0.0705 - precision: 0.7791 - recall: 0.9815 - val_F2: 0.6561 - val_Hamming_loss: 0.1132 - val_Hamming_score: 0.8868 - val_ROC-AUC: 0.8670 - val_loss: 0.0724 - val_precision: 0.7472 - val_recall: 0.9830 - learning_rate: 0.0010
# Epoch 13/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.6614 - Hamming_loss: 0.1036 - Hamming_score: 0.8964 - ROC-AUC: 0.8748 - loss: 0.0692 - precision: 0.7826 - recall: 0.9818 - val_F2: 0.6892 - val_Hamming_loss: 0.1095 - val_Hamming_score: 0.8905 - val_ROC-AUC: 0.8494 - val_loss: 0.0740 - val_precision: 0.7549 - val_recall: 0.9612 - learning_rate: 0.0010
# Epoch 14/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.6687 - Hamming_loss: 0.1022 - Hamming_score: 0.8978 - ROC-AUC: 0.8804 - loss: 0.0679 - precision: 0.7860 - recall: 0.9832 - val_F2: 0.6616 - val_Hamming_loss: 0.1091 - val_Hamming_score: 0.8909 - val_ROC-AUC: 0.8681 - val_loss: 0.0720 - val_precision: 0.7648 - val_recall: 0.9786 - learning_rate: 0.0010
# Epoch 15/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.6762 - Hamming_loss: 0.1000 - Hamming_score: 0.9000 - ROC-AUC: 0.8875 - loss: 0.0663 - precision: 0.7908 - recall: 0.9820 - val_F2: 0.6743 - val_Hamming_loss: 0.1127 - val_Hamming_score: 0.8873 - val_ROC-AUC: 0.8692 - val_loss: 0.0718 - val_precision: 0.7485 - val_recall: 0.9762 - learning_rate: 0.0010
# Epoch 16/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.6822 - Hamming_loss: 0.0987 - Hamming_score: 0.9013 - ROC-AUC: 0.8924 - loss: 0.0652 - precision: 0.7911 - recall: 0.9836 - val_F2: 0.6895 - val_Hamming_loss: 0.1133 - val_Hamming_score: 0.8867 - val_ROC-AUC: 0.8731 - val_loss: 0.0720 - val_precision: 0.7471 - val_recall: 0.9746 - learning_rate: 0.0010
# Epoch 17/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.6860 - Hamming_loss: 0.0966 - Hamming_score: 0.9034 - ROC-AUC: 0.8961 - loss: 0.0644 - precision: 0.7974 - recall: 0.9824 - val_F2: 0.6830 - val_Hamming_loss: 0.1114 - val_Hamming_score: 0.8886 - val_ROC-AUC: 0.8696 - val_loss: 0.0730 - val_precision: 0.7654 - val_recall: 0.9721 - learning_rate: 0.0010
# Epoch 18/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.6943 - Hamming_loss: 0.0956 - Hamming_score: 0.9044 - ROC-AUC: 0.9023 - loss: 0.0629 - precision: 0.7990 - recall: 0.9830 - val_F2: 0.7019 - val_Hamming_loss: 0.1114 - val_Hamming_score: 0.8886 - val_ROC-AUC: 0.8610 - val_loss: 0.0725 - val_precision: 0.7458 - val_recall: 0.9693 - learning_rate: 0.0010
# Epoch 19/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.6996 - Hamming_loss: 0.0942 - Hamming_score: 0.9058 - ROC-AUC: 0.9057 - loss: 0.0620 - precision: 0.8021 - recall: 0.9832 - val_F2: 0.6779 - val_Hamming_loss: 0.1100 - val_Hamming_score: 0.8900 - val_ROC-AUC: 0.8688 - val_loss: 0.0707 - val_precision: 0.7560 - val_recall: 0.9766 - learning_rate: 0.0010
# Epoch 20/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.7028 - Hamming_loss: 0.0924 - Hamming_score: 0.9076 - ROC-AUC: 0.9099 - loss: 0.0607 - precision: 0.8067 - recall: 0.9837 - val_F2: 0.7194 - val_Hamming_loss: 0.1099 - val_Hamming_score: 0.8901 - val_ROC-AUC: 0.8643 - val_loss: 0.0750 - val_precision: 0.7449 - val_recall: 0.9524 - learning_rate: 0.0010
# Epoch 21/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.7123 - Hamming_loss: 0.0908 - Hamming_score: 0.9092 - ROC-AUC: 0.9144 - loss: 0.0596 - precision: 0.8085 - recall: 0.9845 - val_F2: 0.7066 - val_Hamming_loss: 0.1105 - val_Hamming_score: 0.8895 - val_ROC-AUC: 0.8575 - val_loss: 0.0782 - val_precision: 0.7398 - val_recall: 0.9520 - learning_rate: 0.0010
# Epoch 22/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.7195 - Hamming_loss: 0.0884 - Hamming_score: 0.9116 - ROC-AUC: 0.9196 - loss: 0.0576 - precision: 0.8158 - recall: 0.9842 - val_F2: 0.7085 - val_Hamming_loss: 0.1132 - val_Hamming_score: 0.8868 - val_ROC-AUC: 0.8637 - val_loss: 0.0768 - val_precision: 0.7410 - val_recall: 0.9580 - learning_rate: 0.0010
# Epoch 23/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.7237 - Hamming_loss: 0.0860 - Hamming_score: 0.9140 - ROC-AUC: 0.9238 - loss: 0.0563 - precision: 0.8228 - recall: 0.9853 - val_F2: 0.7326 - val_Hamming_loss: 0.1097 - val_Hamming_score: 0.8903 - val_ROC-AUC: 0.8614 - val_loss: 0.0861 - val_precision: 0.7460 - val_recall: 0.9310 - learning_rate: 0.0010
# Epoch 24/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.7273 - Hamming_loss: 0.0845 - Hamming_score: 0.9155 - ROC-AUC: 0.9265 - loss: 0.0555 - precision: 0.8254 - recall: 0.9855 - val_F2: 0.7237 - val_Hamming_loss: 0.1158 - val_Hamming_score: 0.8842 - val_ROC-AUC: 0.8470 - val_loss: 0.0847 - val_precision: 0.7266 - val_recall: 0.9326 - learning_rate: 0.0010
# Epoch 25/100
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 88s 165ms/step - F2: 0.7557 - Hamming_loss: 0.0770 - Hamming_score: 0.9230 - ROC-AUC: 0.9441 - loss: 0.0494 - precision: 0.8397 - recall: 0.9887 - val_F2: 0.7258 - val_Hamming_loss: 0.1132 - val_Hamming_score: 0.8868 - val_ROC-AUC: 0.8556 - val_loss: 0.0850 - val_precision: 0.7371 - val_recall: 0.9419 - learning_rate: 5.0000e-04
#
# --------------------------------Training completed--------------------------------
# Evaluation Set loading.....
#
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - F2: 0.6773 - Hamming_loss: 0.1141 - Hamming_score: 0.8859 - ROC-AUC: 0.8640 - loss: 0.0748 - precision: 0.7555 - recall: 0.9649
#
# --------------------------------Evalution done!--------------------------------
#
# Showing predictions for sample number 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# [[0.7533629  0.18707432 0.22305208 0.0992812  0.11837825 0.11047728]]
#
# --------------------------------Save current model--------------------------------
#
# Saving model....
#
# --------------------------------Model saved successfully!-------------------------

# %% [markdown]
# ## Launch TensorBoard Utility

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs/
# Out:
# Reusing TensorBoard on port 6006 (pid 21427), started 0:00:50 ago. (Use '!kill 21427' to kill it.)
#       <iframe id="tensorboard-frame-9e49c4121994890b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-9e49c4121994890b");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
